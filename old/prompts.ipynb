# %% [markdown]
# I want to build a real-world, production-style Python project to strengthen my skills.
#
# The project should allow me to apply and demonstrate the following concepts:
# - Core Python fundamentals (functions, modules, error handling)
# - Object-Oriented Programming (OOPS)
# - Decorators (for logging, validation, performance tracking, etc.)
# - Design Patterns (such as Factory, Singleton, Strategy, etc.)
# - NumPy (for numerical operations)
# - Pandas (for data processing and transformation)
# - Data Visualization (Matplotlib/Seaborn/Plotly)
#
# Requirements:
# 1. Provide a complete real-world problem statement (preferably from domains like data engineering, finance, analytics, or data quality).
# 2. The use case should be practical and scalable (like something used in industry).
# 3. Break down the project into clear modules/components (e.g., ingestion, processing, validation, reporting).
# 4. Suggest where and how each concept (decorators, OOPS, design patterns, etc.) should be applied.
# 5. Include expected inputs, outputs, and sample datasets.
# 6. Define key features (e.g., automation, logging, alerting, dashboards).
# 7. Provide a high-level architecture diagram explanation (no image needed, just explanation).
# 8. Suggest folder structure and best practices for writing production-level code.
#
# Goal:
# I want to use this project to prepare for senior data engineer/data architect roles and build a strong portfolio project.

# %%
Context: Refactor my prompt 

INput : 

Help me build this prompt 

I m beginner in Python and want to become advance level user
I would love to code dialy with problem statements,
I want you to build 90 days plans where i can learn, apply , build some concepts 

OUtput: REfactored Prompt

# %% [markdown]
# I am a beginner in Python and want to become an advanced-level programmer in a structured and practical way.
# I would like a **comprehensive 90-day learning plan** that focuses on:
#
# * Building strong fundamentals
# * Practicing daily with problem statements
# * Applying concepts through mini-projects
# * Gradually moving to advanced topics
#
# The plan should include:
#     * Daily or weekly learning goals
#     * Recommended topics (basic to advanced)
#     * Hands-on coding exercises and problem statements
#     * Real-world mini projects at different stages
#     * Revision and practice strategy
# Additionally:
#     * Ensure the plan is **practical and coding-focused**, not just theoretical
#     * Include increasing difficulty over time
#     * Suggest tools, libraries, and best practices where relevant
#
# My goal is to become confident in Python for real-world problem solving and development.
